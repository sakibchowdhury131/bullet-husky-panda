# %%
# !pip3 install pyrealsense2 open3d
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyrealsense2 in /home/sakib/.local/lib/python3.8/site-packages (2.55.1.6486)
# Collecting open3d
#   Downloading open3d-0.19.0-cp38-cp38-manylinux_2_31_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: numpy>=1.18.0 in /home/sakib/.local/lib/python3.8/site-packages (from open3d) (1.24.3)
# Collecting dash>=2.6.0 (from open3d)
#   Downloading dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: werkzeug>=3.0.0 in /home/sakib/.local/lib/python3.8/site-packages (from open3d) (3.0.1)
# Collecting flask>=3.0.0 (from open3d)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: nbformat>=5.7.0 in /home/sakib/.local/lib/python3.8/site-packages (from open3d) (5.9.2)
# Collecting configargparse (from open3d)
#   Downloading ConfigArgParse-1.7-py3-none-any.whl.metadata (23 kB)
# Collecting ipywidgets>=8.0.4 (from open3d)
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting addict (from open3d)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: pillow>=9.3.0 in /home/sakib/.local/lib/python3.8/site-packages (from open3d) (10.2.0)
# Requirement already satisfied: matplotlib>=3 in /home/sakib/.local/lib/python3.8/site-packages (from open3d) (3.7.5)
# Requirement already satisfied: pandas>=1.0 in /home/sakib/.local/lib/python3.8/site-packages (from open3d) (2.0.3)
# Collecting pyyaml>=5.4.1 (from open3d)
#   Downloading PyYAML-6.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: scikit-learn>=0.21 in /home/sakib/.local/lib/python3.8/site-packages (from open3d) (1.3.2)
# Requirement already satisfied: tqdm in /home/sakib/.local/lib/python3.8/site-packages (from open3d) (4.66.2)
# Requirement already satisfied: pyquaternion in /home/sakib/.local/lib/python3.8/site-packages (from open3d) (0.9.9)
# Collecting plotly>=5.0.0 (from dash>=2.6.0->open3d)
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting dash-html-components==2.0.0 (from dash>=2.6.0->open3d)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash>=2.6.0->open3d)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash>=2.6.0->open3d)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: importlib-metadata in /home/sakib/.local/lib/python3.8/site-packages (from dash>=2.6.0->open3d) (6.6.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/sakib/.local/lib/python3.8/site-packages (from dash>=2.6.0->open3d) (4.12.2)
# Requirement already satisfied: requests in /home/sakib/.local/lib/python3.8/site-packages (from dash>=2.6.0->open3d) (2.31.0)
# Collecting retrying (from dash>=2.6.0->open3d)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /home/sakib/.local/lib/python3.8/site-packages (from dash>=2.6.0->open3d) (1.6.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from dash>=2.6.0->open3d) (45.2.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/sakib/.local/lib/python3.8/site-packages (from flask>=3.0.0->open3d) (3.1.3)
# Collecting itsdangerous>=2.1.2 (from flask>=3.0.0->open3d)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: click>=8.1.3 in /home/sakib/.local/lib/python3.8/site-packages (from flask>=3.0.0->open3d) (8.1.7)
# Collecting blinker>=1.6.2 (from flask>=3.0.0->open3d)
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: comm>=0.1.3 in /home/sakib/.local/lib/python3.8/site-packages (from ipywidgets>=8.0.4->open3d) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /home/sakib/.local/lib/python3.8/site-packages (from ipywidgets>=8.0.4->open3d) (8.12.3)
# Requirement already satisfied: traitlets>=4.3.1 in /home/sakib/.local/lib/python3.8/site-packages (from ipywidgets>=8.0.4->open3d) (5.14.1)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets>=8.0.4->open3d)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets>=8.0.4->open3d)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sakib/.local/lib/python3.8/site-packages (from matplotlib>=3->open3d) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib>=3->open3d) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sakib/.local/lib/python3.8/site-packages (from matplotlib>=3->open3d) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/lib/python3/dist-packages (from matplotlib>=3->open3d) (1.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/sakib/.local/lib/python3.8/site-packages (from matplotlib>=3->open3d) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3->open3d) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sakib/.local/lib/python3.8/site-packages (from matplotlib>=3->open3d) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/sakib/.local/lib/python3.8/site-packages (from matplotlib>=3->open3d) (6.1.1)
# Requirement already satisfied: fastjsonschema in /home/sakib/.local/lib/python3.8/site-packages (from nbformat>=5.7.0->open3d) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /home/sakib/.local/lib/python3.8/site-packages (from nbformat>=5.7.0->open3d) (4.21.1)
# Requirement already satisfied: jupyter-core in /home/sakib/.local/lib/python3.8/site-packages (from nbformat>=5.7.0->open3d) (5.7.1)
# Requirement already satisfied: pytz>=2020.1 in /home/sakib/.local/lib/python3.8/site-packages (from pandas>=1.0->open3d) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/sakib/.local/lib/python3.8/site-packages (from pandas>=1.0->open3d) (2024.1)
# Requirement already satisfied: scipy>=1.5.0 in /home/sakib/.local/lib/python3.8/site-packages (from scikit-learn>=0.21->open3d) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/sakib/.local/lib/python3.8/site-packages (from scikit-learn>=0.21->open3d) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/sakib/.local/lib/python3.8/site-packages (from scikit-learn>=0.21->open3d) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/sakib/.local/lib/python3.8/site-packages (from werkzeug>=3.0.0->open3d) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in /home/sakib/.local/lib/python3.8/site-packages (from importlib-metadata->dash>=2.6.0->open3d) (3.17.0)
# Requirement already satisfied: backcall in /home/sakib/.local/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.0)
# Requirement already satisfied: decorator in /home/sakib/.local/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/sakib/.local/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/sakib/.local/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.1.6)
# Requirement already satisfied: pickleshare in /home/sakib/.local/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/sakib/.local/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/sakib/.local/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.17.2)
# Requirement already satisfied: stack-data in /home/sakib/.local/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (4.6.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/sakib/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/sakib/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (2023.12.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/sakib/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in /home/sakib/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/sakib/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.17.1)
# Collecting narwhals>=1.15.1 (from plotly>=5.0.0->dash>=2.6.0->open3d)
#   Downloading narwhals-1.26.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3->open3d) (1.14.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/sakib/.local/lib/python3.8/site-packages (from jupyter-core->nbformat>=5.7.0->open3d) (4.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sakib/.local/lib/python3.8/site-packages (from requests->dash>=2.6.0->open3d) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->dash>=2.6.0->open3d) (2.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->dash>=2.6.0->open3d) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sakib/.local/lib/python3.8/site-packages (from requests->dash>=2.6.0->open3d) (2024.12.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/sakib/.local/lib/python3.8/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.8.3)
# Requirement already satisfied: wcwidth in /home/sakib/.local/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/sakib/.local/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/sakib/.local/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.4.1)
# Requirement already satisfied: pure-eval in /home/sakib/.local/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.2)
# Downloading open3d-0.19.0-cp38-cp38-manylinux_2_31_x86_64.whl (447.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.7/447.7 MB 15.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading dash-2.18.2-py3-none-any.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 23.8 MB/s eta 0:00:00 MB/s eta 0:00:0101mm
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 12.1 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 14.0 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (746 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 746.5/746.5 kB 58.3 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading ConfigArgParse-1.7-py3-none-any.whl (25 kB)
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 19.4 MB/s eta 0:00:00
# Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 87.2 MB/s eta 0:00:000m eta 0:00:010:0101
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 81.9 MB/s eta 0:00:00
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading narwhals-1.26.0-py3-none-any.whl (306 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.6/306.6 kB 36.7 MB/s eta 0:00:00
# Installing collected packages: dash-table, dash-html-components, dash-core-components, addict, widgetsnbextension, retrying, pyyaml, narwhals, jupyterlab-widgets, itsdangerous, configargparse, blinker, plotly, flask, dash, ipywidgets, open3d
# Successfully installed addict-2.4.0 blinker-1.8.2 configargparse-1.7 dash-2.18.2 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 flask-3.0.3 ipywidgets-8.1.5 itsdangerous-2.2.0 jupyterlab-widgets-3.0.13 narwhals-1.26.0 open3d-0.19.0 plotly-6.0.0 pyyaml-6.0.2 retrying-1.3.4 widgetsnbextension-4.0.13
#
# [notice] A new release of pip is available: 24.0 -> 25.0
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import pyrealsense2 as rs
import numpy as np
import cv2
import open3d as o3d

# Initialize RealSense pipeline
pipeline = rs.pipeline()
config = rs.config()

# Enable depth and color streams
config.enable_stream(rs.stream.depth, 640, 480, rs.format.z16, 30)
config.enable_stream(rs.stream.color, 640, 480, rs.format.bgr8, 30)

# Start streaming
pipeline.start(config)

# Get depth scale for converting depth values to meters
profile = pipeline.get_active_profile()
depth_sensor = profile.get_device().first_depth_sensor()
depth_scale = depth_sensor.get_depth_scale()

# Intrinsic parameters
intrinsics = profile.get_stream(rs.stream.depth).as_video_stream_profile().get_intrinsics()
fx, fy, cx, cy = intrinsics.fx, intrinsics.fy, intrinsics.ppx, intrinsics.ppy

def depth_to_3d(x, y, depth):
    """ Convert pixel (x, y) and depth to 3D world coordinates. """
    z = depth * depth_scale
    if z == 0:  # Ignore invalid depth points
        return None
    X = (x - cx) * z / fx
    Y = (y - cy) * z / fy
    return np.array([X, Y, z])

def detect_ball(color_image):
    """ Detect a ball in the color image using color thresholding. """
    hsv = cv2.cvtColor(color_image, cv2.COLOR_BGR2HSV)
    
    # Define color range for the ball (adjust as needed)
    lower_red = np.array([0, 120, 70])
    upper_red = np.array([10, 255, 255])
    
    mask = cv2.inRange(hsv, lower_red, upper_red)

    # Find contours
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        largest_contour = max(contours, key=cv2.contourArea)
        (x, y), radius = cv2.minEnclosingCircle(largest_contour)
        if radius > 5:  # Filter out small noise
            return int(x), int(y), int(radius)
    return NoneHSV

try:
    while True:
        frames = pipeline.wait_for_frames()
        depth_frame = frames.get_depth_frame()
        color_frame = frames.get_color_frame()

        if not depth_frame or not color_frame:
            continue

        # Convert frames to numpy arrays
        depth_image = np.asanyarray(depth_frame.get_data())
        color_image = np.asanyarray(color_frame.get_data())

        # Detect the ball
        ball = detect_ball(color_image)
        if ball:
            x, y, radius = ball

            # Get depth value at the detected position
            depth_value = depth_image[y, x]
            ball_position = depth_to_3d(x, y, depth_value)

            if ball_position is not None:
                print(f"Ball detected at: {ball_position}")

                # Draw the detected ball on the color image
                cv2.circle(color_image, (x, y), radius, (0, 255, 0), 2)
                cv2.putText(color_image, f"3D: {ball_position[0]:.2f}, {ball_position[1]:.2f}, {ball_position[2]:.2f}", 
                            (x + 10, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        # Show images
        cv2.imshow("Color Image", color_image)
        cv2.imshow("Depth Image", cv2.applyColorMap(cv2.convertScaleAbs(depth_image, alpha=0.03), cv2.COLORMAP_JET))

        # Press 'q' to exit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

finally:
    pipeline.stop()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[14], line 75
#      72 color_image = np.asanyarray(color_frame.get_data())
#      74 # Detect the ball
# ---> 75 ball = detect_ball(color_image)
#      76 if ball:
#      77     x, y, radius = ball
#
# Cell In[14], line 52, in detect_ball(color_image)
#      48 cv2.imshow("mahsvsk Image", gray)
#      51 # Find contours
# ---> 52 contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#      53 if contours:
#      54     largest_contour = max(contours, key=cv2.contourArea)
#
# error: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'findContours'
# > Overload resolution failed:
# >  - image data type = bool is not supported
# >  - Expected Ptr<cv::UMat> for argument 'image'

# %%
import cv2
import numpy as np

def get_hsv_value(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:  # Left mouse click
        hsv_pixel = hsv[y, x]  # Get HSV value at clicked position
        print(f"HSV at ({x}, {y}): {hsv_pixel}")

# Open camera
cap = cv2.VideoCapture(0)  # Change 0 to your RealSense camera index

while True:
    ret, frame = cap.read()
    if not ret:
        break

    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)  # Convert to HSV
    
    cv2.imshow("Frame", frame)
    cv2.setMouseCallback("Frame", get_hsv_value)  # Set mouse click event
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@1278.500] global cap_v4l.cpp:999 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@1278.501] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
